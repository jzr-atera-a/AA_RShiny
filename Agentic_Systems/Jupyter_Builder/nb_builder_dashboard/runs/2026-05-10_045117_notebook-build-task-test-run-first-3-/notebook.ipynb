# %% [markdown]
# ### Cell 1 establishes all imports needed for the entire notebook. This includes ArcGIS modules for GIS connection, feature layers, and geometry operations, plus pandas for data handling and urllib for any REST API calls. All imports are consolidated here per the guidelines - no imports should appear in later cells.

# %%
# ── Cell 1: All imports ───────────────────────────────────────────────────────
from arcgis.gis import GIS
from arcgis.features import FeatureLayer, FeatureSet, Feature
from arcgis.geometry import Point, Polygon, Geometry
import pandas as pd
import json
import os
import urllib.request
import urllib.parse

print("✅ Imports complete")
